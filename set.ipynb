# %%
#empty set
data = set()
print(type(data))
# Out:
# <class 'set'>

# %%
data = {12,12,1,1,2,3,4,5,4,4,5,3,2,2,2,2,2,2}
print(data)
# Out:
# {1, 2, 3, 4, 5, 12}

# %%
data = [12,12,1,1,2,3,4,5,4,4,5,3,2,2,2,2,2,2]
data_set = set(data)
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 12}

# %%
# add()
data_set.add(999)
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 999, 12}

# %%
# update()
data_set.update([222,22,45])
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 999, 12, 45, 22, 222}

# %%
data = list(data_set)
print(data)
# Out:
# [1, 2, 3, 4, 5, 999, 12, 45, 22, 222]

# %%
print(data[5:8])
print(data[8])
print(data[5])
# Out:
# [999, 12, 45]
# 22
# 999

# %%
data = {12,13,14,15,12,1,2}
data.discard(14)
print(data)
# Out:
# {1, 2, 12, 13, 15}

# %%
data = {12,13,14,15,12,1,2}
data.remove(1)
print(data)
# Out:
# {2, 12, 13, 14, 15}

# %%
# pop()
data.pop()
print(data)
# Out:
# {13, 14, 15}

# %%
#clear
data.clear()
print(data)
# Out:
# set()
