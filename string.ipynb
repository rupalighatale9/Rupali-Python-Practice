# %%
data = "Python"
print(data)
# Out:
# Python

# %%
print(data[2])
# Out:
# t

# %%
# 1. upper() converts the string to uppercase
print(data.upper())

# 2. lower() converts the string to lowercase
print(data.lower())
# Out:
# PYTHON
# python

# %%
data = "Rupa with python"
# 3. partition() returns a tuple
print(data.partition("w"))

# 4. replace() replaces substring inside
print(data.replace("python","IT Vedant"))

# 5. find() returns the index of first occurence of substring
print(data.find('p'))

# 6. rstrip() removes trailing characters
data = 'welcome   '
print(data,'hello')
print(data.rstrip(),'hello')

# 7. split() splits string from left
data = 'python r go java julia ruby'
print(data.split(' '))

# 8. startswith() checks if string starts with the specified string
print(data.startswith("codes"))
number = 'F78'
# Out:
# ('Rupa ', 'w', 'ith python')
# Rupa with IT Vedant
# 2
# welcome    hello
# welcome hello
# ['python', 'r', 'go', 'java', 'julia', 'ruby']
# False

# %%
# 9. isnumeric() checks numeric characters
print(number.isnumeric())
# Out:
# False

# %%
# 10. index() returns index of substring
print(data.index('t'))
# Out:
# 2

# %%
# 11. format() print data

name = 'Rupali'
age = 22
height = 5.3

print("your name is {0}, height {2},age {1}".format(name,age,height))

print(f'your name is {name} height {height} age {age}')
# Out:
# your name is Rupali, height 5.3,age 22
# your name is Rupali height 5.3 age 22
