# %%
print("welcome")
# Out:
# welcome

# %%
data=[]
print(data)
# Out:
# []

# %%
data = ["java","c++","python","r","jsp","rubby"]
print(data)
# Out:
# ['java', 'c++', 'python', 'r', 'jsp', 'rubby']

# %%
print(data[2])
print(data[-3])
# Out:
# python
# r

# %%
print(data[2:4])
print(data[:4])
print(data[3:5])
print(data[1:6])
print(data[:])
# Out:
# ['python', 'r']
# ['java', 'c++', 'python', 'r']
# ['r', 'jsp']
# ['c++', 'python', 'r', 'jsp', 'rubby']
# ['java', 'c++', 'python', 'r', 'jsp', 'rubby']

# %%
data = ["java","c++","python","r","jsp","rubby"]
#update
data[4] = "go"
print(data)
# Out:
# ['java', 'c++', 'python', 'r', 'go', 'rubby']

# %%
#append
data.append("julia")
print(data)
# Out:
# ['java', 'c++', 'python', 'r', 'go', 'rubby', 'julia']

# %%
#extend
data.extend(["jsf","spring","API"])
print(data)
# Out:
# ['java', 'c++', 'python', 'r', 'go', 'rubby', 'julia', 'jsf', 'spring', 'API']

# %%
#insert
data.insert(3,"CWPC")
print(data)
# Out:
# ['java', 'c++', 'python', 'CWPC', 'r', 'go', 'rubby', 'julia', 'jsf', 'spring', 'API']

# %%
#remove()
data.remove("java")
print(data)
# Out:
# ['c++', 'python', 'CWPC', 'r', 'go', 'rubby', 'julia', 'jsf', 'spring', 'API']

# %%
#pop()
data.pop()
print(data)
# Out:
# ['c++', 'python', 'CWPC', 'r', 'go', 'rubby', 'julia', 'jsf', 'spring']

# %%
#index()
print(data.index("python")
      )
# Out:
# 1

# %%
data = ["c++","python","cwpc","go","jsp","rubby","julia","julia","julia","julia"]
# count()
print(data.count("julia"))
# Out:
# 4

# %%
# sort()
data = [21,222,8,5,6,7,8,9,0]
data.sort()
print(data)

# reverse
data.reverse()
print(data)
# Out:
# [0, 5, 6, 7, 8, 8, 9, 21, 222]
# [222, 21, 9, 8, 8, 7, 6, 5, 0]

# %%
# copy()
d1 = data.copy()
print(d1)
# Out:
# [222, 21, 9, 8, 8, 7, 6, 5, 0]

# %%
# clear()
data.clear()
print(data)
# Out:
# []

# %%
data = [21,222,8,5,6,7,8,9,0]
print(min(data))
print(max(data))
print(sum(data))
print(len(data))
# Out:
# 0
# 222
# 286
# 9

# %%
data = "Rupali ghatale"
print(len(data))
# Out:
# 14
