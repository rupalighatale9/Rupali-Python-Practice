# %%
class car:
    def amount():
        print("10,00,000/-")

    def model():
        print("Rupali - ")
        print("BMW - ")

    def colour():
        print("Black - ")

#create a object
my_car = car
my_car.amount()
my_car.model()
my_car.colour()
# Out:
# 10,00,000/-
# Rupali -
# BMW -
# Black -

# %%
class car:
    def __init__(a):
        price = 50000
        a.price = price
        print("Rupali - ")
        print("BMW - ")
        print("Black colour - ")
        print(f"your price is = {price}")

    def credit_price(a,c_price):
        a.c_price = c_price
        print(f"credit price :{c_price}/-")

    def car_amount(a):
        final_price = a.price + a.c_price
        print(f"Car amount {final_price} ")

# %%
my_car = car()
my
my_car.car_amount()
# Out:
# Rupali -
# BMW -
# Black colour -
# Car amount is 10,00,000/-
