# %%
#write file
file = open("cwpc.txt","w")
file.write("Welcome to python programming..../n")
file.write("Welcome to java programming..../n")
file.write("Welcome to c++ programming..../n")
file.close()

# %%
#read file
file = open("cwpc.txt","r")
data = file.read()
print(data)
# Out:
# Welcome to python programming..../nWelcome to java programming..../nWelcome to c++ programming..../n

# %%
#append file a
file = open("cwpc.txt","a")
file.write("java - is best ...")
file.close()

# %%
#write 
with open("cwpc.txt","r") as file:
    print(file.read())
# Out:
# Welcome to python programming..../nWelcome to java programming..../nWelcome to c++ programming..../njava - is best ...

# %%
name = str(input("Enter your name - "))
age = int(input("Enter your age - "))
height = int(input("Enter your height is - "))
BMI  = age/height
print(f"BMI = {BMI}")
print(f"your name is {name} and age is {age}, height is {height} ")
# Out:
# Enter your name -  rupa
# Enter your age -  rups
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 name = str(input("Enter your name - "))
# ----> 2 age = int(input("Enter your age - "))
#       3 height = int(input("Enter your height is - "))
#       4 BMI  = age/height
#
# ValueError: invalid literal for int() with base 10: 'rups'

# %%
try:
    name = str(input("Enter your name - "))
    age = int(input("Enter your age - "))
    height = int(input("Enter your height is - "))
    BMI  = age/height
    print(f"BMI = {BMI}")
    print(f"your name is {name} and age is {age}, height is {height} ")

except ValueError :
    print("Enter only number - plz")
except ZeroDivisionError :
    print("do not enter Zero - plz ")
# Out:
# Enter your name -  rupa
# Enter your age -  22
# Enter your height is -  5
# BMI = 4.4
# your name is rupa and age is 22, height is 5
